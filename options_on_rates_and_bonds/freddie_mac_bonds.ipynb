# %% [markdown]
# ## Case Study - Freddie Mac Bonds

# %%
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Pricing the Callable Bond
